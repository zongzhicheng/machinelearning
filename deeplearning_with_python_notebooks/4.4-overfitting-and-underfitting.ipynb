# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.3.1'

# %%
from keras.datasets import imdb
import numpy as np

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)
# Out:
# D:\anaconda3\envs\TF_2C\lib\site-packages\keras\datasets\imdb.py:101: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# D:\anaconda3\envs\TF_2C\lib\site-packages\keras\datasets\imdb.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %%
def vectorize_sequences(sequences, dimension=10000):
    # 创建一个形状为((len(sequences), dimension))的零矩阵
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.  # 将result[i]的指定索引设为1
    return results

# 将训练数据向量化
x_train = vectorize_sequences(train_data)
# 将测试数据向量化
x_test = vectorize_sequences(test_data)

y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %% [markdown]
# ### 4.4 过拟合与欠拟合

# %% [markdown]
# #### 4.4.1 减小网络大小

# %%
from keras import models
from keras import layers

# 原始模型
original_model = models.Sequential()
original_model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
original_model.add(layers.Dense(16, activation='relu'))
original_model.add(layers.Dense(1, activation='sigmoid'))

original_model.compile(optimizer='rmsprop',
                       loss='binary_crossentropy',
                       metrics=['acc'])

# %%
# 容量更小的模型
smaller_model = models.Sequential()
smaller_model.add(layers.Dense(4, activation='relu', input_shape=(10000,)))
smaller_model.add(layers.Dense(4, activation='relu'))
smaller_model.add(layers.Dense(1, activation='sigmoid'))

smaller_model.compile(optimizer='rmsprop',
                      loss='binary_crossentropy',
                      metrics=['acc'])

# %%
original_hist = original_model.fit(x_train, y_train,
                                   epochs=20,
                                   batch_size=512,
                                   validation_data=(x_test, y_test))
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 [==============================] - 4s 176us/step - loss: 0.4767 - acc: 0.8136 - val_loss: 0.3581 - val_acc: 0.8774
# Epoch 2/20
# 25000/25000 [==============================] - 3s 126us/step - loss: 0.2736 - acc: 0.9073 - val_loss: 0.2886 - val_acc: 0.8897
# Epoch 3/20
# 25000/25000 [==============================] - 3s 130us/step - loss: 0.2086 - acc: 0.9276 - val_loss: 0.2839 - val_acc: 0.8865
# Epoch 4/20
# 25000/25000 [==============================] - 3s 110us/step - loss: 0.1751 - acc: 0.9387 - val_loss: 0.3008 - val_acc: 0.8804
# Epoch 5/20
# 25000/25000 [==============================] - 3s 110us/step - loss: 0.1512 - acc: 0.9473 - val_loss: 0.3349 - val_acc: 0.8714
# Epoch 6/20
# 25000/25000 [==============================] - 3s 107us/step - loss: 0.1318 - acc: 0.9554 - val_loss: 0.3332 - val_acc: 0.8752
# Epoch 7/20
# 25000/25000 [==============================] - 3s 108us/step - loss: 0.1178 - acc: 0.9602 - val_loss: 0.3628 - val_acc: 0.8707
# Epoch 8/20
# 25000/25000 [==============================] - 3s 110us/step - loss: 0.1031 - acc: 0.9658 - val_loss: 0.4618 - val_acc: 0.8501
# Epoch 9/20
# 25000/25000 [==============================] - 3s 111us/step - loss: 0.0933 - acc: 0.9694 - val_loss: 0.4050 - val_acc: 0.8646
# Epoch 10/20
# 25000/25000 [==============================] - 3s 107us/step - loss: 0.0818 - acc: 0.9742 - val_loss: 0.4223 - val_acc: 0.8648
# Epoch 11/20
# 25000/25000 [==============================] - 3s 104us/step - loss: 0.0735 - acc: 0.9765 - val_loss: 0.4524 - val_acc: 0.8629
# Epoch 12/20
# 25000/25000 [==============================] - 3s 103us/step - loss: 0.0648 - acc: 0.9807 - val_loss: 0.4807 - val_acc: 0.8609
# Epoch 13/20
# 25000/25000 [==============================] - 3s 102us/step - loss: 0.0564 - acc: 0.9827 - val_loss: 0.5230 - val_acc: 0.8568
# Epoch 14/20
# 25000/25000 [==============================] - 3s 101us/step - loss: 0.0498 - acc: 0.9851 - val_loss: 0.5361 - val_acc: 0.8572
# Epoch 15/20
# 25000/25000 [==============================] - 3s 101us/step - loss: 0.0434 - acc: 0.9872 - val_loss: 0.6227 - val_acc: 0.8506
# Epoch 16/20
# 25000/25000 [==============================] - 3s 102us/step - loss: 0.0371 - acc: 0.9904 - val_loss: 0.6477 - val_acc: 0.8512
# Epoch 17/20
# 25000/25000 [==============================] - 3s 102us/step - loss: 0.0330 - acc: 0.9902 - val_loss: 0.6334 - val_acc: 0.8534
# Epoch 18/20
# 25000/25000 [==============================] - 3s 103us/step - loss: 0.0275 - acc: 0.9932 - val_loss: 0.7185 - val_acc: 0.8490
# Epoch 19/20
# 25000/25000 [==============================] - 3s 102us/step - loss: 0.0238 - acc: 0.9940 - val_loss: 0.7412 - val_acc: 0.8491
# Epoch 20/20
# 25000/25000 [==============================] - 3s 102us/step - loss: 0.0193 - acc: 0.9955 - val_loss: 0.9274 - val_acc: 0.8361

# %%
smaller_model_hist = smaller_model.fit(x_train, y_train,
                                       epochs=20,
                                       batch_size=512,
                                       validation_data=(x_test, y_test))
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 [==============================] - 3s 101us/step - loss: 0.5134 - acc: 0.7919 - val_loss: 0.4032 - val_acc: 0.8671
# Epoch 2/20
# 25000/25000 [==============================] - 2s 99us/step - loss: 0.3213 - acc: 0.8983 - val_loss: 0.3197 - val_acc: 0.8833
# Epoch 3/20
# 25000/25000 [==============================] - 3s 100us/step - loss: 0.2451 - acc: 0.9180 - val_loss: 0.2952 - val_acc: 0.8856
# Epoch 4/20
# 25000/25000 [==============================] - 2s 98us/step - loss: 0.2056 - acc: 0.9318 - val_loss: 0.2840 - val_acc: 0.8877
# Epoch 5/20
# 25000/25000 [==============================] - 2s 99us/step - loss: 0.1799 - acc: 0.9398 - val_loss: 0.2845 - val_acc: 0.8859
# Epoch 6/20
# 25000/25000 [==============================] - 2s 99us/step - loss: 0.1610 - acc: 0.9468 - val_loss: 0.2880 - val_acc: 0.8853
# Epoch 7/20
# 25000/25000 [==============================] - 2s 99us/step - loss: 0.1462 - acc: 0.9524 - val_loss: 0.2971 - val_acc: 0.8824
# Epoch 8/20
# 25000/25000 [==============================] - 2s 99us/step - loss: 0.1329 - acc: 0.9563 - val_loss: 0.3077 - val_acc: 0.8794
# Epoch 9/20
# 25000/25000 [==============================] - 2s 99us/step - loss: 0.1221 - acc: 0.9606 - val_loss: 0.3249 - val_acc: 0.8766
# Epoch 10/20
# 25000/25000 [==============================] - 2s 100us/step - loss: 0.1123 - acc: 0.9644 - val_loss: 0.3332 - val_acc: 0.8762
# Epoch 11/20
# 25000/25000 [==============================] - 3s 100us/step - loss: 0.1043 - acc: 0.9672 - val_loss: 0.3735 - val_acc: 0.8646
# Epoch 12/20
# 25000/25000 [==============================] - 2s 99us/step - loss: 0.0967 - acc: 0.9698 - val_loss: 0.3636 - val_acc: 0.8703
# Epoch 13/20
# 25000/25000 [==============================] - 2s 99us/step - loss: 0.0893 - acc: 0.9727 - val_loss: 0.3787 - val_acc: 0.8692
# Epoch 14/20
# 25000/25000 [==============================] - 2s 100us/step - loss: 0.0828 - acc: 0.9751 - val_loss: 0.3980 - val_acc: 0.8680
# Epoch 15/20
# 25000/25000 [==============================] - 3s 100us/step - loss: 0.0773 - acc: 0.9770 - val_loss: 0.4126 - val_acc: 0.8664
# Epoch 16/20
# 25000/25000 [==============================] - 3s 103us/step - loss: 0.0722 - acc: 0.9791 - val_loss: 0.4319 - val_acc: 0.8618
# Epoch 17/20
# 25000/25000 [==============================] - 3s 104us/step - loss: 0.0669 - acc: 0.9814 - val_loss: 0.4477 - val_acc: 0.8632
# Epoch 18/20
# 25000/25000 [==============================] - 3s 104us/step - loss: 0.0624 - acc: 0.9832 - val_loss: 0.4654 - val_acc: 0.8606
# Epoch 19/20
# 25000/25000 [==============================] - 3s 103us/step - loss: 0.0577 - acc: 0.9847 - val_loss: 0.4875 - val_acc: 0.8601
# Epoch 20/20
# 25000/25000 [==============================] - 3s 105us/step - loss: 0.0534 - acc: 0.9861 - val_loss: 0.5056 - val_acc: 0.8571

# %%
epochs = range(1, 21)
original_val_loss = original_hist.history['val_loss']
smaller_model_val_loss = smaller_model_hist.history['val_loss']

# %%
import matplotlib.pyplot as plt

plt.plot(epochs, original_val_loss, 'b+', label='Original model')
plt.plot(epochs, smaller_model_val_loss, 'bo', label='Smaller model')
plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
# 容器更大的模型
bigger_model = models.Sequential()
bigger_model.add(layers.Dense(512, activation='relu', input_shape=(10000,)))
bigger_model.add(layers.Dense(512, activation='relu'))
bigger_model.add(layers.Dense(1, activation='sigmoid'))

bigger_model.compile(optimizer='rmsprop',
                     loss='binary_crossentropy',
                     metrics=['acc'])

# %%
bigger_model_hist = bigger_model.fit(x_train, y_train,
                                     epochs=20,
                                     batch_size=512,
                                     validation_data=(x_test, y_test))
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 [==============================] - 7s 267us/step - loss: 0.4690 - acc: 0.7901 - val_loss: 0.2987 - val_acc: 0.8870
# Epoch 2/20
# 25000/25000 [==============================] - 7s 266us/step - loss: 0.2222 - acc: 0.9128 - val_loss: 0.2930 - val_acc: 0.8824
# Epoch 3/20
#  - ETA: 0s - loss: 0.1308 - acc: 0.9517
# Epoch 4/20
# 25000/25000 [==============================] - 7s 266us/step - loss: 0.0780 - acc: 0.9750 - val_loss: 0.3235 - val_acc: 0.8813
# Epoch 5/20
# 25000/25000 [==============================] - 7s 262us/step - loss: 0.0720 - acc: 0.9880 - val_loss: 0.4091 - val_acc: 0.8587
# Epoch 6/20
# 25000/25000 [==============================] - 7s 272us/step - loss: 0.0056 - acc: 0.9998 - val_loss: 0.6496 - val_acc: 0.8759
# Epoch 7/20
# 25000/25000 [==============================] - 7s 267us/step - loss: 0.0435 - acc: 0.9949 - val_loss: 3.6946 - val_acc: 0.6622
# Epoch 8/20
# 25000/25000 [==============================] - 7s 270us/step - loss: 0.0304 - acc: 0.9958 - val_loss: 0.7386 - val_acc: 0.8789
# Epoch 9/20
# 25000/25000 [==============================] - 7s 267us/step - loss: 0.0941 - acc: 0.9893 - val_loss: 0.5970 - val_acc: 0.8777
# Epoch 10/20
# 25000/25000 [==============================] - 7s 273us/step - loss: 8.0862e-04 - acc: 0.9999 - val_loss: 1.6076 - val_acc: 0.7873
# Epoch 11/20
# 25000/25000 [==============================] - 7s 270us/step - loss: 0.0489 - acc: 0.9904 - val_loss: 0.7521 - val_acc: 0.8802
# Epoch 12/20
# 25000/25000 [==============================] - 7s 298us/step - loss: 1.1760e-04 - acc: 1.0000 - val_loss: 0.9595 - val_acc: 0.8785
# Epoch 13/20
# 25000/25000 [==============================] - 8s 326us/step - loss: 0.1231 - acc: 0.9901 - val_loss: 0.9037 - val_acc: 0.8634
# Epoch 14/20
# 25000/25000 [==============================] - 8s 305us/step - loss: 7.6540e-04 - acc: 1.0000 - val_loss: 0.9621 - val_acc: 0.8656
# Epoch 15/20
# 25000/25000 [==============================] - 8s 307us/step - loss: 4.6141e-05 - acc: 1.0000 - val_loss: 0.9719 - val_acc: 0.8788
# Epoch 16/20
# 25000/25000 [==============================] - 8s 302us/step - loss: 0.1060 - acc: 0.9904 - val_loss: 0.8023 - val_acc: 0.8733
# Epoch 17/20
# 25000/25000 [==============================] - 7s 299us/step - loss: 3.2010e-04 - acc: 1.0000 - val_loss: 0.8660 - val_acc: 0.8779
# Epoch 18/20
# 25000/25000 [==============================] - 8s 301us/step - loss: 1.9512e-05 - acc: 1.0000 - val_loss: 0.9904 - val_acc: 0.8781
# Epoch 19/20
# 25000/25000 [==============================] - 8s 302us/step - loss: 4.7464e-06 - acc: 1.0000 - val_loss: 1.1458 - val_acc: 0.8761
# Epoch 20/20
# 25000/25000 [==============================] - 8s 304us/step - loss: 1.0447e-06 - acc: 1.0000 - val_loss: 1.5819 - val_acc: 0.8548

# %%
bigger_model_val_loss = bigger_model_hist.history['val_loss']

plt.plot(epochs, original_val_loss, 'b+', label='Original model')
plt.plot(epochs, bigger_model_val_loss, 'bo', label='Bigger model')
plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
original_train_loss = original_hist.history['loss']
bigger_model_train_loss = bigger_model_hist.history['loss']

plt.plot(epochs, original_train_loss, 'b+', label='Original model')
plt.plot(epochs, bigger_model_train_loss, 'bo', label='Bigger model')
plt.xlabel('Epochs')
plt.ylabel('Training loss')
plt.legend()

plt.show()

# %% [markdown]
# #### 4.4.2 添加权重正则化

# %% [markdown]
# * L1正则化（L1 regularization）：添加的成本与**权重系数的绝对值**【权重的L1范数】成正比
#
#     L1范数是指向量中各个元素绝对值之和，也叫“稀疏规则算子”（Lasso regularization）。
#
#     比如向量A=[1, -1, 3] ， 那么A的L1范数为|1|+|-1|+|3|=5
#
# * L2正则化（L2 regularization）：添加的成本与**权重系数的平方**【权重的L2范数】成正比
#
#     比如向量A=[1, -1, 3] ， 那么A的L2范数为√(|1|²+|-1|²+|3|²)=√11

# %%
from keras import regularizers

l2_model = models.Sequential()
l2_model.add(layers.Dense(16, kernel_regularizer=regularizers.l2(0.001),
                          activation='relu', input_shape=(10000,)))
l2_model.add(layers.Dense(16, kernel_regularizer=regularizers.l2(0.001),
                          activation='relu'))
l2_model.add(layers.Dense(1, activation='sigmoid'))

# %%
l2_model.compile(optimizer='rmsprop',
                 loss='binary_crossentropy',
                 metrics=['acc'])

# %%
l2_model_hist = l2_model.fit(x_train, y_train,
                             epochs=20,
                             batch_size=512,
                             validation_data=(x_test, y_test))
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 [==============================] - 3s 123us/step - loss: 0.4911 - acc: 0.8186 - val_loss: 0.4153 - val_acc: 0.8457
# Epoch 2/20
# 25000/25000 [==============================] - 2s 92us/step - loss: 0.3163 - acc: 0.9025 - val_loss: 0.3459 - val_acc: 0.8819
# Epoch 3/20
# 25000/25000 [==============================] - 2s 93us/step - loss: 0.2732 - acc: 0.9197 - val_loss: 0.3436 - val_acc: 0.8820
# Epoch 4/20
# 25000/25000 [==============================] - 2s 92us/step - loss: 0.2504 - acc: 0.9278 - val_loss: 0.3355 - val_acc: 0.8865
# Epoch 5/20
# 25000/25000 [==============================] - 2s 91us/step - loss: 0.2395 - acc: 0.9325 - val_loss: 0.3880 - val_acc: 0.8651
# Epoch 6/20
# 25000/25000 [==============================] - 2s 91us/step - loss: 0.2318 - acc: 0.9349 - val_loss: 0.3475 - val_acc: 0.8830
# Epoch 7/20
# 25000/25000 [==============================] - 2s 92us/step - loss: 0.2270 - acc: 0.9368 - val_loss: 0.3975 - val_acc: 0.8652
# Epoch 8/20
# 25000/25000 [==============================] - 3s 110us/step - loss: 0.2217 - acc: 0.9385 - val_loss: 0.3893 - val_acc: 0.8686
# Epoch 9/20
# 25000/25000 [==============================] - 2s 91us/step - loss: 0.2166 - acc: 0.9418 - val_loss: 0.4071 - val_acc: 0.8649
# Epoch 10/20
# 25000/25000 [==============================] - 2s 92us/step - loss: 0.2113 - acc: 0.9442 - val_loss: 0.3737 - val_acc: 0.8755
# Epoch 11/20
# 25000/25000 [==============================] - 2s 92us/step - loss: 0.2101 - acc: 0.9434 - val_loss: 0.4032 - val_acc: 0.8692
# Epoch 12/20
# 25000/25000 [==============================] - 2s 91us/step - loss: 0.2116 - acc: 0.9419 - val_loss: 0.3894 - val_acc: 0.8739
# Epoch 13/20
# 25000/25000 [==============================] - 2s 91us/step - loss: 0.2022 - acc: 0.9474 - val_loss: 0.3912 - val_acc: 0.8732
# Epoch 14/20
# 25000/25000 [==============================] - 2s 91us/step - loss: 0.2000 - acc: 0.9491 - val_loss: 0.3981 - val_acc: 0.8706
# Epoch 15/20
# 25000/25000 [==============================] - 2s 91us/step - loss: 0.1997 - acc: 0.9474 - val_loss: 0.3946 - val_acc: 0.8729
# Epoch 16/20
# 25000/25000 [==============================] - 2s 91us/step - loss: 0.1976 - acc: 0.9494 - val_loss: 0.4012 - val_acc: 0.8726
# Epoch 17/20
# 25000/25000 [==============================] - 2s 92us/step - loss: 0.1930 - acc: 0.9505 - val_loss: 0.4153 - val_acc: 0.8650
# Epoch 18/20
# 25000/25000 [==============================] - 2s 92us/step - loss: 0.1918 - acc: 0.9508 - val_loss: 0.4136 - val_acc: 0.8698
# Epoch 19/20
# 25000/25000 [==============================] - 2s 91us/step - loss: 0.1899 - acc: 0.9512 - val_loss: 0.4390 - val_acc: 0.8620
# Epoch 20/20
# 25000/25000 [==============================] - 2s 91us/step - loss: 0.1891 - acc: 0.9514 - val_loss: 0.4553 - val_acc: 0.8564

# %%
l2_model_val_loss = l2_model_hist.history['val_loss']

plt.plot(epochs, original_val_loss, 'b+', label='Original model')
plt.plot(epochs, l2_model_val_loss, 'bo', label='L2-regularized model')
plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend()

plt.show()

# %%
from keras import regularizers

# L1 正则化
regularizers.l1(0.001)

# 同时做 L1 和 L2 正则化
regularizers.l1_l2(l1=0.001, l2=0.001)

# %% [markdown]
# #### 4.4.3 添加dropout正则化

# %%
# 向IMDB网络中添加dropout
dpt_model = models.Sequential()
dpt_model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
dpt_model.add(layers.Dropout(0.5))
dpt_model.add(layers.Dense(16, activation='relu'))
dpt_model.add(layers.Dropout(0.5))
dpt_model.add(layers.Dense(1, activation='sigmoid'))

dpt_model.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['acc'])

# %%
dpt_model_hist = dpt_model.fit(x_train, y_train,
                               epochs=20,
                               batch_size=512,
                               validation_data=(x_test, y_test))
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 [==============================] - 4s 145us/step - loss: 0.5764 - acc: 0.6972 - val_loss: 0.4241 - val_acc: 0.8599
# Epoch 2/20
# 25000/25000 [==============================] - 3s 110us/step - loss: 0.4163 - acc: 0.8298 - val_loss: 0.3125 - val_acc: 0.8864
# Epoch 3/20
# 25000/25000 [==============================] - 2s 99us/step - loss: 0.3352 - acc: 0.8726 - val_loss: 0.2831 - val_acc: 0.8872
# Epoch 4/20
# 25000/25000 [==============================] - 2s 99us/step - loss: 0.2841 - acc: 0.8942 - val_loss: 0.2773 - val_acc: 0.8896
# Epoch 5/20
# 25000/25000 [==============================] - 2s 95us/step - loss: 0.2483 - acc: 0.9109 - val_loss: 0.2928 - val_acc: 0.8857
# Epoch 6/20
# 25000/25000 [==============================] - 3s 108us/step - loss: 0.2210 - acc: 0.9222 - val_loss: 0.2940 - val_acc: 0.8889
# Epoch 7/20
# 25000/25000 [==============================] - 3s 110us/step - loss: 0.2008 - acc: 0.9278 - val_loss: 0.3198 - val_acc: 0.8845
# Epoch 8/20
# 25000/25000 [==============================] - 3s 114us/step - loss: 0.1780 - acc: 0.9365 - val_loss: 0.3301 - val_acc: 0.8863
# Epoch 9/20
# 25000/25000 [==============================] - 3s 101us/step - loss: 0.1643 - acc: 0.9393 - val_loss: 0.3714 - val_acc: 0.8806
# Epoch 10/20
# 25000/25000 [==============================] - 2s 97us/step - loss: 0.1563 - acc: 0.9432 - val_loss: 0.3960 - val_acc: 0.8795
# Epoch 11/20
# 25000/25000 [==============================] - 3s 100us/step - loss: 0.1483 - acc: 0.9456 - val_loss: 0.3987 - val_acc: 0.8793
# Epoch 12/20
# 25000/25000 [==============================] - 2s 97us/step - loss: 0.1345 - acc: 0.9506 - val_loss: 0.4267 - val_acc: 0.8825
# Epoch 13/20
# 25000/25000 [==============================] - 3s 107us/step - loss: 0.1332 - acc: 0.9554 - val_loss: 0.4463 - val_acc: 0.8774
# Epoch 14/20
# 25000/25000 [==============================] - 2s 98us/step - loss: 0.1236 - acc: 0.9592 - val_loss: 0.4799 - val_acc: 0.8784
# Epoch 15/20
# 25000/25000 [==============================] - 2s 91us/step - loss: 0.1223 - acc: 0.9614 - val_loss: 0.5017 - val_acc: 0.8745
# Epoch 16/20
# 25000/25000 [==============================] - 2s 91us/step - loss: 0.1128 - acc: 0.9632 - val_loss: 0.5015 - val_acc: 0.8784
# Epoch 17/20
# 25000/25000 [==============================] - 2s 92us/step - loss: 0.1137 - acc: 0.9626 - val_loss: 0.5177 - val_acc: 0.8747
# Epoch 18/20
# 25000/25000 [==============================] - 2s 92us/step - loss: 0.1076 - acc: 0.9644 - val_loss: 0.5364 - val_acc: 0.8738
# Epoch 19/20
# 25000/25000 [==============================] - 2s 92us/step - loss: 0.1027 - acc: 0.9674 - val_loss: 0.5863 - val_acc: 0.8739
# Epoch 20/20
# 25000/25000 [==============================] - 2s 91us/step - loss: 0.1000 - acc: 0.9684 - val_loss: 0.6076 - val_acc: 0.8730

# %%
dpt_model_val_loss = dpt_model_hist.history['val_loss']

plt.plot(epochs, original_val_loss, 'b+', label='Original model')
plt.plot(epochs, dpt_model_val_loss, 'bo', label='Dropout-regularized model')
plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend()

plt.show()
