# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Using TensorFlow backend.
# Corpus length: 600893

# %%
# 提取60个字符组成的序列
maxlen = 60

# 每3个字符采样一个新序列
step = 3

# 保存所提取的序列
sentences = []

# 保存目标（即下一个字符）
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# 语料中唯一字符组成的列表
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# 一个字典，将唯一字符映射为它在列表chars中的索引
char_indices = dict((char, chars.index(char)) for char in chars)

# 将字符one-hot编码为二进制数组
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 58
# Vectorization...

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # 将模型在数据上拟合一次
    model.fit(x, y,
              batch_size=128,
              epochs=1)
    # 随机选择一个文本种子
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    # 尝试一系列不同的采样温度
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # 从种子文本开始，生成400个字符
        for i in range(400):
            # 对目前生产的字符编码进行one-hot编码
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            # 对下一个字符进行采样
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 138s 687us/step - loss: 1.9502
# --- Generating with seed: " unfortunately, otherwise:
# for there is no eternal justice.
# "
# ------ temperature: 0.2
#  unfortunately, otherwise:
# for there is no eternal justice.
#
#
# 12. the sone the sould the self-moral and the solless of the sain the sones and the sone the moral of the solled the sollection of the spirit of the have not and the profore the sonsting of the sone of the sould the spirit the sain the contemm the self-moral the self-conteple of the longer the self-mankind the self-mankind the spirit of the spirit of the sould the power the contemm the sain the
# ------ temperature: 0.5
#  the spirit of the sould the power the contemm the sain the philosophan
# the sonselves and the for the for the would be a would an a whole the presided and soch of the facture, the called the power of even and stronger the suffices the sentions for his moral one as the intermsticism the far an inceals of the profor self-mone and moral the was for mankind not worth the manking restinger and the certain that have called and boove bethe for
# our pooples of a pl
# ------ temperature: 1.0
# ain that have called and boove bethe for
# our pooples of a ploraded, in very them, he require things; huhe spxcient--the what manver sokence socies afdoing "fort all the duclitemxial of kind have looving
# that the
# for, and verth of the "luting be for
# nearivater--more, be a foltiens of pilous
# verage on benasided which germany themselves, one sense to de
# evient those a fectici lang. one eveny
# that overy the spectiol to the sold philosophe[s." in or wound that
# ------ temperature: 1.2
# ry the spectiol to the sold philosophe[s." in or wound that inrecoghapualg; force
# what but and
# raivent strod. diption to pever gryafure
# could mangent, buthes" thinksed, which bo knov and bils whith this taphir chain: mospid, men our with themly lang.
#
# ;
# lled sandty. hoqutgons and the fole 1hemper also spoty or : i vastian thinhs anumad, must called of exious, she preark moralterful reloge (at bufle, god honceanhhat of a not to
# doslemmanes. thrtr ngirok hik
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 142s 707us/step - loss: 1.6088
# --- Generating with seed: "ned to make inability to wait the central motive of
# their po"
# ------ temperature: 0.2
# ned to make inability to wait the central motive of
# their power--the sense of the sense of the sense of the fore the consider the most formular to an and the case--the desires to an and and the many the same and and the soul itself and the sense of the same it is the sense of the same in the sense of the sense of the same and the sense of the sense of the case and the same the compares to an and itself and the same the god and the same and the cannot the d
# ------ temperature: 0.5
# tself and the same the god and the same and the cannot the does the same least the getoer because and the ward in form of the sensest the fore and the fore the spirits it is a man to one make is
# its becesen belief they self-cases itself to sleart as and the sense of to says--rations and nothing the senses one the only the sense of the considerst for the same sensition of endisyme--the themselvests and they and purition and the most the most itself, as a ma
# ------ temperature: 1.0
#  and they and purition and the most the most itself, as a mannessity, of temptions. and laws on the onpert.
# yhellou," swells
# to got, superspiting to be desire generation and given of the
# firde but intere teffic eart delight to pearing care
# the not desirful, that founht on these courser
# and existence for the mediops is we
# take slorgerimy--to2be, in our very but beancile, ordeces,
# sxamflal into the quritions, by moral for
#
# ving;  nothive mystery man laintly
# ------ temperature: 1.2
# quritions, by moral for
#
# ving;  nothive mystery man laintly comaruab what bedens to meanmy
# allsism.-deation
# uncenturibe, tat
# donie; what i lattlecnal scopceplimed, the lotived.
# diingdments of arvouatpo, jungs
# tharist
# exmenualtoionan, to
# mucheralits make imp. namal
# houngec), which vose humanpty of but course, as agaguants, is chuish? dained,rive the disprocmdem=ly =sough
# to triading if the,
# itself and altativence,", werning-"pyalg.
#
# y"-'engeponing,
# exbendin
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 153s 763us/step - loss: 1.5247
# --- Generating with seed: "epainting, the terrible original text homo natura
# must again"
# ------ temperature: 0.2
# epainting, the terrible original text homo natura
# must against the sense of the soul and the sense its speak the soul and the sense of the sense of the soul the soul the belief in the sense of the for the cause of the stronger and the still could a soul as the soul as the the man of the spirit of the sense of the present the such a conscience, and the original a more will be the commands of the sense of the spirit of the soul and the soul and a stronger an
# ------ temperature: 0.5
# nse of the spirit of the soul and the soul and a stronger and with the been as the self-longer of the morals he was it is the looking has a prefection. it is conduct to the far every the be in the longed bethe himself the of the good even of a harrified his way to can compared the a could life in the world strength the man has a thore the far a conscience of speak it is not the the developments, and as the use of such man has how self-corturing of the form
# ------ temperature: 1.0
# nd as the use of such man has how self-corturing of the former the question mawned
# and that a mankind eventuness, and all tooblies the really horough so
# than it has certain his man falikinw-may a
# distiusters as miral bline that yough faith, "whether morality to
# the
# streeply and crose the brow of world--a christified stronger pains, as theught, abled to scoremod; a give plare, speakedmes to if aid view refered a holtary kind that all first and that sually d
# ------ temperature: 1.2
# view refered a holtary kind that all first and that sually dorgnation, costrains ans. "many philosophy that. a indivirual un nevernotion. the subjuged, alavjurs of socient phyilon, then rekevebness is acvaided, and it after shift and conscience.-with
# the most prefandirianam
# mores, is a ban revilityw-pant no duare longer. not
# sensency if sicked." but
# they we eman, for opinion, the commanding--thinks himself by the evert
# juegva the
# bidd in wnywe: heherradds
# epoch 4
# Epoch 1/1
#  - ETA: 27s - loss: 1.4776
# --- Generating with seed: "t if i cease to love you
# my deportment, although from some o"
# ------ temperature: 0.2
# t if i cease to love you
# my deportment, although from some one and the possible to all the stronged to the probad the one of the probad to the stronged and the one of the stronged and soul, in the present in the stingest and all the stands to the stands to the contrain to have to the also a sensition of the same to the general and the interestious to the soul in the same the will to be a will to the profual and the all the stinged, in the same and the stro
# ------ temperature: 0.5
# he profual and the all the stinged, in the same and the stronging which the than of this conscience in a will for the part of beliety of the same taken of the
# our the philosophers, the most must be distrust and in the stands in the hand, the placed to he of the conscience of the charments of the them, will of poliation of the gratition of the stronging the impulses
# to even believe to be the origination and the longer senses and sensetion of old as at in th
# ------ temperature: 1.0
# ation and the longer senses and sensetion of old as at in the chavity in made and
# featicication virtued: it is
# there heroviss, and wene discrhapes in itself our naturre-sterious destenction of delitativity of this her conclas a idenes of the liveny in the
# gratitocary imseludien intentions of there a goodyoual naithyurement of feet un""" to operass in himself, all toome, but what a success, must at an of
# times may not the time of human stancituragical nair
# ------ temperature: 1.2
#  an of
# times may not the time of human stancituragical nairound; volous our been stood of grof, the stindmentnaws, is
# oliginations.--rigits. boditr: is ne
# comfuichents; it i discover
# traes as accoridnications? and through t
# abreising, could longene: mirre wect stepe--aimfiance, mele for a aares, thi speciates, ssrigitued, our sackitudaken's noget, raction in which is soing now
#
# same to
# about the most stingeroared! whesen soledy subquitcedual full,ness agc
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 147s 735us/step - loss: 1.4506
# --- Generating with seed: "estors, the
# "blood," decide here also. many generations must"
# ------ temperature: 0.2
# estors, the
# "blood," decide here also. many generations must be a the man and conscience of the destructions of the most desirations of the present the strength and the most desirations of the most mankind in the destructions of the most called and destructions of the most called and same the more and perhaps individual the personal more and individual and soul and the experience of the most present of the most many the most mankind and spirit of the from
# ------ temperature: 0.5
# nt of the most many the most mankind and spirit of the from does some some with the contemption of destructions and present and acts from
# metaphysicless which there is a respection of the self-personal present the most the conception of the most due and the pribacity of distant with the emotions of suppositions and distrustful men, and seems there is for himself is to the means of a the same the faith in the power the motive of actions of
# the error the dou
# ------ temperature: 1.0
# aith in the power the motive of actions of
# the error the doubt inspent style of
# simptaticulal "philosed in overates is afce
# man
# their
# worsce. men only itself distoly had varily find, but the child, the sacrifice bestrained inkeve-ye one which even the unemosing and paminated forker.
#
# matimitutiver of morally termarty tranking. there
# mey so man when he minduaus always," on "unone appeary
# that at themmpa; this life, take are includals in lipther than spetiwa
# ------ temperature: 1.2
# emmpa; this life, take are includals in lipther than spetiwalty our us
# to the agimational "matters minncould, that all clents. the compares firstedly--then stand that is true.qurddliou
# lihege are arts ills beforectionall, which is this medertions person, rarous
# does
# nepermoinofy doblewing eedieity of perhamminar, an-irpeation, we were
# awally valuss
# with! if atove-sord in-thiness from neition.  mock, when we thought,
# -betray of
# such another-dles of him anat
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 148s 741us/step - loss: 1.4282
# --- Generating with seed: "of rational capacity
# determine the direction in which this l"
# ------ temperature: 0.2
# of rational capacity
# determine the direction in which this long the most present than and that the most consider to the most present than the most perhaps, the most sour of the most powerful and present and the most sense of the most present than the spirit, and the man and perhaps the most perhaps we can one is the most present and such and seem to the most conscience of the master and the most consert the spirit, and the strength and contradiction of the
# ------ temperature: 0.5
# onsert the spirit, and the strength and contradiction of the great paint and some more and really for powerful be the characters in the most powerful, spirits of such all existence than all destition, it is a will so have altogeradict and the more spirit of the belief in the conduct of the brought and god, as the most impossible of the religious to democre are the self-religion of a conception to the most conduct then as there is to be a work and the manif
# ------ temperature: 1.0
# the most conduct then as there is to be a work and the manifold affe
# trumks, and than he right and though, the long in, the phishes must be as to its re; the my fel, sacroxianity, is a
# spirits of ten monocrism from times--which conseiveranciar youlter thaning in my axchamed with case christianion: that a psychological pirdust in not and monttion
# can
# disposition of ha
# peithy, of a dispossible
# of the sensus plimp natural religings and not readily-reivitaly f
# ------ temperature: 1.2
# e sensus plimp natural religings and not readily-reivitaly for exclim. know that preasmpoowableves and to speeking, ducull find
# to bidumnous, pow, , rich understand is
# little ovinatisungs--mo"tariandiun? but recantromeshus. is
# from histiquuded there is congrace thish thing, soub-ysens as ikes altaption.
# weal: th=seminates all
# that of "farweled whyse genementances" in as been. they aason as even itself powerful
# bas is certain cintles!
#
# s
# freeling of present
# epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 150s 747us/step - loss: 1.4110
# --- Generating with seed: "rld absolutely established, it would nevertheless
# remain inc"
# ------ temperature: 0.2
# rld absolutely established, it would nevertheless
# remain incelt of the same the man and are and the strong and the strong and with the same the one and the man has for the sense of the mankind of the sense of the sense of the more and the world of the same things to the men of the same and formerly the same the strong and in the super-will and the more the fact the strong and the world of the precisely to him which the same the same things and with the sam
# ------ temperature: 0.5
# isely to him which the same the same things and with the same altogest hand has preciption of the from the most proposing with the generation of the contriters of "things himself, and itself of the state of the religious mankind of the enemy has for the perhaps, and the moral only the only under the same antithes the jessure of the conscience of the sense of the only and the refinement than the consideration of the spirit and the explent of the same indivi
# ------ temperature: 1.0
# nsideration of the spirit and the explent of the same individual--we are himself, and a belief to interpretive in this extairaty of the inderence than youes--that takits over the self-nature to one of the jesuite cressciestion of the decession--hand among
# this perhaps, handful woman milinguhing and de only evil would have gurst belong at one must stye is could be and lar dols means" which
# now
# peoplen himself, not one is only in form kniwicisecan
# name preci
# ------ temperature: 1.2
# len himself, not one is only in form kniwicisecan
# name precisely aalnay fround time and
# follous dot] unterpious are deliled from thingse the intentional, i mhate eknowgetoe, impulse i watd pared had "what hang
# liable spriws his po oud soulther other has seadal
# purct tour empticalty: ther many easily the haptiness altumation. but the arbles
# fundaments has who feels
# else," sund propisyer, effect him who not phrise
# eplose hor melmogking: renound arough at hi
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 147s 734us/step - loss: 1.3983
# --- Generating with seed: "se things are wafted away from the soul and he feels himself"
# ------ temperature: 0.2
# se things are wafted away from the soul and he feels himself the senses of the desire and superstition of the german superstition of the artists and the strifting and contrary the same the most the possibility of the senses of the delight and learned and the most the world of the sense of the persons of the most the desire and the german superstition of the delights and and the desire of the conscience, the powerful the desire and most conscience and the g
# ------ temperature: 0.5
# ience, the powerful the desire and most conscience and the german forth, the sinful and philosophers of the proper prooded, the spiritual deceive the right of its spiritual and them with the contrepetic which which all the samething and not to the deepty of concealed the senses of the fact in the deceives by the contrive to the bignity of the progressions of the feeling the science and are man and something for man, as it is allow in the something the sens
# ------ temperature: 1.0
#  something for man, as it is allow in the something the senses, for defirates intorthical readian more god, and
# from
# them in the older to its wort that a supposenture bagtably, lartable sceper
# mane himself that, -is even to which different meduines inthut thecility, is and beven coniscimity of the waking "something for as, i sensational history" of goesimming your pleasure and good on twe great reuption of boows of all spspondion of the
# beriedn which pardi
# ------ temperature: 1.2
# uption of boows of all spspondion of the
# beriedn which parding, and gond, what is suk? but its sublime only our
# istherness toith, "for
# itsable passes taone, almoved
# incelf, gigived plebsuanimes follomment that we stren,h.
#
# at to
# younharial,i-nator who are pley saken: he religilicry which they incaint
# in it we doen; and what i stielly a peticaljusked, atomiments
# ofe? and six sail,
# pinhours. capable, is clayicnesser: outs senses: beto
# capethray out of ippsde
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 148s 741us/step - loss: 1.3851
# --- Generating with seed: "bled with ardor and fever--that was the last pleasure
# left t"
# ------ temperature: 0.2
# bled with ardor and fever--that was the last pleasure
# left the sense of the sense of the sense of the restrary of the sense of the prespect the most believes and the most the freedom of the sense of the most dealing the sense of the most matter and the souls and something delight of the positive and discovered the sense of the consistes of the sense of the consequently and souls of the sense of the souls and conscience of the most the most the and sorrow t
# ------ temperature: 0.5
# e souls and conscience of the most the most the and sorrow the its of complements and called for store
# from the germans of the great still
# upon the most all the pretritess. but the acts of the experienous and place and the one think of the great deprease and in convertation of the same the before the significes of this the world in which he the same the thing what is are souls in the fact of compared the german disposition and great before the most bad fal
# ------ temperature: 1.0
# red the german disposition and great before the most bad falseddy who form of
# the destructious, express? if there signification are old in: liver noty", as is despected build compalfaning, at matter explued in which the ways sexualtome, to which considerator to milble about of experieings, is prove to faturfel. the
# domain extrasd, in
# on
# in all being combirly moral, as one of his deal from philosophious to pays to complement
# dince flligited). that none a d
# ------ temperature: 1.2
# phious to pays to complement
# dince flligited). that none a delight
# of honestjed, and unifoutogy it people okemench, againstly aptorp: there armily
# and there oto so alwaysn ettire, loge"d the german , this diffictics and especially them good certainto
# grear wnoger is concervent
# that without that good! in them
# these repences, paratapine, feeling has, through sochary there is givitiotal opinionjuscous
# deming and
# sendeat as para-do"ges of the own compalion--th
# epoch 10
# Epoch 1/1
# 144256/200278 [====================>.........] - ETA: 41s - loss: 1.3696
