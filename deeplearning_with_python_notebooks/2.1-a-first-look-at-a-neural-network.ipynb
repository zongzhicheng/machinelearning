# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.3.1'

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 97s 8us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %%
from keras import models
from keras import layers

network = models.Sequential()
# 两个全连接层（Dense）
# 相当于把28*28拉伸为784*1
network.add(layers.Dense(512,activation='relu',input_shape=(28*28,)))
network.add(layers.Dense(10,activation='softmax'))

# %%
network.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %%
from keras.utils import to_categorical

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
network.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 6s 96us/step - loss: 0.2530 - accuracy: 0.9268
# Epoch 2/5
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.1030 - accuracy: 0.9690
# Epoch 3/5
# 60000/60000 [==============================] - 4s 72us/step - loss: 0.0682 - accuracy: 0.9790
# Epoch 4/5
# 60000/60000 [==============================] - 4s 71us/step - loss: 0.0494 - accuracy: 0.9851
# Epoch 5/5
# 60000/60000 [==============================] - 4s 71us/step - loss: 0.0380 - accuracy: 0.9886

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
# Out:
# 10000/10000 [==============================] - 1s 61us/step
# test_acc: 0.9782999753952026

# %%
import numpy as np
# 标量（0D张量）
x = np.array(12)
x.ndim
# Out:
# 0

# %%
# 向量（1D张量）
x = np.array([12,3,6,14,7])
x.ndim
# Out:
# 1

# %%
#矩阵（2D张量）
x = np.array([[5,12],[4,6],[12,3]])
x.ndim
# Out:
# 2

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
digit = train_images[4]

import matplotlib.pyplot as plt
plt.imshow(digit,cmap=plt.cm.binary)
plt.show()

# %%
# 第10~100个数字（不包括第100个）
my_slice = train_images[10:100]
print(my_slice.shape)
# 等同于
my_slice = train_images[10:100,:,:]
my_slice.shape
# 等同于
my_slice = train_images[10:100,0:28,0:28]
my_slice.shape
# Out:
# (90, 28, 28)
# (90, 28, 28)

# %%
import numpy as np
# x是形状为(64,3,32,10)的随机张量
x = np.random.random((64,3,32,10))
# y是形状为(32,10)的随机张量
y = np.random.random((32,10))
# 输出z的形状为(64,3,32,10),与x相同
z = np.maximum(x,y)

# %%
x = np.zeros((300,20))
x = np.transpose(x)
print(x.shape)
# Out:
# (20, 300)
